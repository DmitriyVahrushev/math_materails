# %%
# %matplotlib inline
from scipy import stats
import numpy as np
import pandas as pd
from scipy.stats import kstest
import seaborn
from matplotlib.pyplot import show 
import math

# %%
data = pd.read_csv("r2z2.csv")
lambda_ = 0.5
alpha = 0.1

# %%
#Критическая константа?

# %%
from statsmodels.distributions.empirical_distribution import ECDF  #  эмпирическая функция распределения
from scipy.stats import expon
import matplotlib.pyplot as plt

file = ECDF(data['X'])
data['y_values'] = data['X'].apply(file)
#seaborn.lineplot(data['X'],data['y_values'], drawstyle='steps-pre')
seaborn.lineplot(data['X'],data['y_values'], drawstyle='steps-post')

ECDF(data['X'], side='right')
data_exp = np.random.exponential(scale = 1/lambda_, size=5000)
ecdf = ECDF(data_exp)
plt.plot(ecdf.x,ecdf.y)

data_norm = np.random.normal(0,1, size = 3000)
ecdf = ECDF(data_norm)
#plt.plot(ecdf.x,ecdf.y)

# %%
loc = 0
scale =1/1.5
print(stats.kstest(data['X'], "expon", args=(0, (1/1.5))))
print('p < 0:01 — высоко значимое расхождение с гипотезой;')
# Out:
# KstestResult(statistic=0.3888581222187135, pvalue=1.3949288371330276e-13)
# p < 0:01 — высоко значимое расхождение с гипотезой;

# %%
import scipy.stats as scp
x = seaborn.distplot(data['X'],bins = 20, kde=True)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
D, p_value = stats.kstest(data['X'], 'expon', args = (0, (1/1.5)))
print('\nK
      S-statistic D =', D, 'p-value = ', p_value)

quant = math.sqrt((-1/2*math.log(alpha/2, math.e)))
print('\nFkolm^(-1)(1 - alpha) = ',quant)

if math.sqrt(len(data))*D > quant:
    print(math.sqrt(len(data))*D, ' > ', quant)
    print('Н0 отклоняется')
# Out:
# KS-statistic D = 0.3888581222187135 p-value =  1.3949288371330276e-13
#
# Fkolm^(-1)(1 - alpha) =  1.2238734153404083
# 3.8100159270906646  >  1.2238734153404083
# Н0 отклоняется
